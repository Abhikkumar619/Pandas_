# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
df.drop('PassengerId')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.drop('PassengerId')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
# ...

# %%
df.drop('PassengerId', axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df #wint delete parmanent to delecte parmanently
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId', axis=1, inplace=False)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.set_index('Name', inplace=True)

# %%
df.head(3)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
#
#                                                               Ticket     Fare  \
# Name
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
d={
    'key1':[1,2,3,4,5],
    'key2':[5,6,7,7,9],
    'key3':[7,8,91,2,4]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     5     7
# 1     2     6     8
# 2     3     7    91
# 3     4     7     2
# 4     5     9     4

# %%
df1=pd.read_csv('taxonomy.csv')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df2.fillna('NULL')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency      NULL                  NULL
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#find out how many are are servived by using group by function.
obj=df2.groupby('Survived')

# %%
obj

# %%
obj.sum()
# Out:
# /tmp/ipykernel_1442/91067180.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   obj.sum()
#           PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0              245412    1390  12985.50    304    181  12142.7199
# 1              151974     667   8219.67    162    159  16551.2294

# %%
len(df2['Survived']==0)
# Out:
# 891

# %%
obj.mean()
# Out:
# /tmp/ipykernel_1442/1582909037.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   obj.mean()
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
obj2=df2.groupby('Pclass')

# %%
obj2

# %%
obj2.sum()
# Out:
# /tmp/ipykernel_1442/1883008630.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   obj2.sum()
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99705       136  7111.42     90     77  18177.4125
# 2             82056        87  5168.83     74     70   3801.8417
# 3            215625       119  8924.92    302    193   6714.6951

# %%
obj2.mean()
# Out:
# /tmp/ipykernel_1442/1883362016.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   obj2.mean()
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
obj2.max()
# Out:
# /tmp/ipykernel_1442/1233860988.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   obj2.max()
#         PassengerId  Survived                         Name   Sex   Age  SibSp  \
# Pclass
# 1               890         1     Young, Miss. Marie Grice  male  80.0      3
# 2               887         1    del Carlo, Mr. Sebastiano  male  70.0      3
# 3               891         1  van Melkebeke, Mr. Philemon  male  74.0      8
#
#         Parch      Ticket      Fare
# Pclass
# 1           4   WE/P 5735  512.3292
# 2           3   W/C 14208   73.5000
# 3           6  W./C. 6609   69.5500

# %%
obj2.max()['Fare']
# Out:
# /tmp/ipykernel_1442/4291770918.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   obj2.max()['Fare']
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
obj2.max().T #to make invert.(t means transpose.)  even we can use transpose insist of T.
# Out:
# /tmp/ipykernel_1442/1019498514.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   obj2.max().T
# Pclass                              1                          2  \
# PassengerId                       890                        887
# Survived                            1                          1
# Name         Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Sex                              male                       male
# Age                              80.0                       70.0
# SibSp                               3                          3
# Parch                               4                          3
# Ticket                      WE/P 5735                  W/C 14208
# Fare                         512.3292                       73.5
#
# Pclass                                 3
# ...

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df5=df2[['PassengerId', 'Survived', 'Pclass']][0:5]

# %%
df5
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
df6=df2[['PassengerId', 'Survived', 'Pclass']][5:10]

# %%
df6
# Out:
#    PassengerId  Survived  Pclass
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2

# %%
pd.concat([df5,df6]) # by defult axis =0 which means rows wise (horizentlly)
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2

# %%
pd.concat([df5,df6], axis=1)  #axis 1 means column wise operation.
# Out:
#    PassengerId  Survived  Pclass  PassengerId  Survived  Pclass
# 0          1.0       0.0     3.0          NaN       NaN     NaN
# 1          2.0       1.0     1.0          NaN       NaN     NaN
# 2          3.0       1.0     3.0          NaN       NaN     NaN
# 3          4.0       1.0     1.0          NaN       NaN     NaN
# 4          5.0       0.0     3.0          NaN       NaN     NaN
# 5          NaN       NaN     NaN          6.0       0.0     3.0
# 6          NaN       NaN     NaN          7.0       0.0     1.0
# 7          NaN       NaN     NaN          8.0       0.0     3.0
# 8          NaN       NaN     NaN          9.0       1.0     3.0
# 9          NaN       NaN     NaN         10.0       1.0     2.0

# %%
df7=pd.concat([df5,df6], axis=1)

# %%
df7.fillna('NULL')
# Out:
#   PassengerId Survived Pclass PassengerId Survived Pclass
# 0         1.0      0.0    3.0        NULL     NULL   NULL
# 1         2.0      1.0    1.0        NULL     NULL   NULL
# 2         3.0      1.0    3.0        NULL     NULL   NULL
# 3         4.0      1.0    1.0        NULL     NULL   NULL
# 4         5.0      0.0    3.0        NULL     NULL   NULL
# 5        NULL     NULL   NULL         6.0      0.0    3.0
# 6        NULL     NULL   NULL         7.0      0.0    1.0
# 7        NULL     NULL   NULL         8.0      0.0    3.0
# 8        NULL     NULL   NULL         9.0      1.0    3.0
# 9        NULL     NULL   NULL        10.0      1.0    2.0

# %%
import pandas as pd
data1=pd.DataFrame({
    'key1':[1,2,3,4],
    'key2': [5,6,7,8],
    'key3':[9,10,11,12]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
data2=pd.DataFrame({
    'key1':[11,23,3,4],
    'key4': [75,6,37,8],
    'key5':[91,210,61,12]
})

# %%
data2
# Out:
#    key1  key4  key5
# 0    11    75    91
# 1    23     6   210
# 2     3    37    61
# 3     4     8    12

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     3     7    11    37    61
# 1     4     8    12     8    12

# %%
pd.merge(data1,data2, how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     5     9   NaN   NaN
# 1     2     6    10   NaN   NaN
# 2     3     7    11  37.0  61.0
# 3     4     8    12   8.0  12.0

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0    11   NaN   NaN    75    91
# 1    23   NaN   NaN     6   210
# 2     3   7.0  11.0    37    61
# 3     4   8.0  12.0     8    12

# %%
pd.merge(data1,data2,how= 'outer')
# Out:
#    key1  key2  key3  key4   key5
# 0     1   5.0   9.0   NaN    NaN
# 1     2   6.0  10.0   NaN    NaN
# 2     3   7.0  11.0  37.0   61.0
# 3     4   8.0  12.0   8.0   12.0
# 4    11   NaN   NaN  75.0   91.0
# 5    23   NaN   NaN   6.0  210.0

# %%
pd.merge(data1,data2, how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     5     9      11    75    91
# 1        1     5     9      23     6   210
# 2        1     5     9       3    37    61
# 3        1     5     9       4     8    12
# 4        2     6    10      11    75    91
# 5        2     6    10      23     6   210
# 6        2     6    10       3    37    61
# 7        2     6    10       4     8    12
# 8        3     7    11      11    75    91
# 9        3     7    11      23     6   210
# 10       3     7    11       3    37    61
# 11       3     7    11       4     8    12
# 12       4     8    12      11    75    91
# 13       4     8    12      23     6   210
# 14       4     8    12       3    37    61
# 15       4     8    12       4     8    12

# %%
data1=pd.DataFrame({
    'key1':[1,2,3,4],
    'key2': [5,6,7,8],
    'key3':[9,10,11,12]
},index=['a','b','c','d'])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     5     9
# b     2     6    10
# c     3     7    11
# d     4     8    12

# %%
data2=pd.DataFrame({
    'key11':[1,2,3,4],
    'key22': [5,6,7,8],
    'key33':[9,10,11,12]
},index=['a','b','g','h'])

# %%
data2
# Out:
#    key11  key22  key33
# a      1      5      9
# b      2      6     10
# g      3      7     11
# h      4      8     12

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     5     9    1.0    5.0    9.0
# b     2     6    10    2.0    6.0   10.0
# c     3     7    11    NaN    NaN    NaN
# d     4     8    12    NaN    NaN    NaN

# %%
data1.join(data2, how='right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   5.0   9.0      1      5      9
# b   2.0   6.0  10.0      2      6     10
# g   NaN   NaN   NaN      3      7     11
# h   NaN   NaN   NaN      4      8     12

# %%
data1.join(data2, how='cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     5     9      1      5      9
# 1      1     5     9      2      6     10
# 2      1     5     9      3      7     11
# 3      1     5     9      4      8     12
# 4      2     6    10      1      5      9
# 5      2     6    10      2      6     10
# 6      2     6    10      3      7     11
# 7      2     6    10      4      8     12
# 8      3     7    11      1      5      9
# 9      3     7    11      2      6     10
# 10     3     7    11      3      7     11
# 11     3     7    11      4      8     12
# 12     4     8    12      1      5      9
# 13     4     8    12      2      6     10
# 14     4     8    12      3      7     11
# 15     4     8    12      4      8     12

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Rupees']=df['Fare'].apply(lambda x: x*152)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def ero_to_nep(x):
    return x*152

# %%
df['Rupees']=df['Fare'].apply(ero_to_nep)

# %%
df[['Rupees']][1:4]
# Out:
#        Rupees
# 1  10835.0616
# 2   1204.6000
# 3   8071.2000

# %%
df['Name_length']=df['Name'].apply(len)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked      Rupees  Name_length
# 0      0         A/5 21171   7.2500   NaN        S   1102.0000           23
# 1      0          PC 17599  71.2833   C85        C  10835.0616           51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   1204.6000           22
# ...

# %%
def cat_fare(x):
    if x<10: 
        return 'cheap'
    elif x>=10 and x<20:
        return 'mid'
    else:
        return 'high'

# %%
df['cat_fare']=df['Fare'].apply(cat_fare)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked      Rupees  Name_length  \
# 0      0         A/5 21171   7.2500   NaN        S   1102.0000           23
# 1      0          PC 17599  71.2833   C85        C  10835.0616           51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   1204.6000           22
# ...
